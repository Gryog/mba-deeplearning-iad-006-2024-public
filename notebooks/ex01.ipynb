# %%
import numpy as np
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

digits = load_digits()
print(digits.data.shape)

digits = load_digits()
X, y = digits.data, digits.target

plt.gray()
plt.matshow(digits.images[0])
plt.show()
# Out:
# (1797, 64)

# %% [markdown]
# Exercício 1 - Treinamento do modelo baseado em árvore de decisão

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score

digits = load_digits()
X, y = digits.data, digits.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model_decision_tree = DecisionTreeClassifier()
model_decision_tree.fit(X_train, y_train)

y_pred = model_decision_tree.predict(X_test)

print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print('Classification Report:')
print(classification_report(y_test, y_pred))

plot_tree(model_decision_tree, filled=True)
# Out:
# Accuracy: 0.837037037037037
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93        53
#            1       0.80      0.72      0.76        50
#            2       0.75      0.81      0.78        47
#            3       0.73      0.85      0.79        54
#            4       0.80      0.82      0.81        60
#            5       0.95      0.85      0.90        66
#            6       0.86      0.94      0.90        53
#            7       0.88      0.84      0.86        55
#            8       0.80      0.84      0.82        43
#            9       0.83      0.81      0.82        59
#
#     accuracy                           0.84       540
#    macro avg       0.84      0.84      0.84       540
# weighted avg       0.84      0.84      0.84       540
# ...

# %% [markdown]
# Exercício 3 - Visualização da árvore de decisão e Medida de Impureza

# %%
model_decision_tree.tree_.impurity
# Out:
# array([0.89984551, 0.55353057, 0.39753941, 0.29166667, 0.        ,
#        0.5       , 0.        , 0.        , 0.09861933, 0.        ,
#        0.05124654, 0.        , 0.        , 0.2660108 , 0.73469388,
#        0.66666667, 0.        , 0.56      , 0.        , 0.5       ,
#        0.        , 0.        , 0.        , 0.11846154, 0.03186785,
#        0.        , 0.5       , 0.        , 0.        , 0.66666667,
#        0.66666667, 0.        , 0.5       , 0.        , 0.        ,
#        0.        , 0.88737272, 0.73966552, 0.65631611, 0.73071871,
#        0.45898438, 0.07986111, 0.        , 0.        , 0.65625   ,
#        0.        , 0.625     , 0.        , 0.5       , 0.        ,
#        0.        , 0.51397977, 0.13079667, 0.5       , 0.        ,
#        0.        , 0.        , 0.41666667, 0.        , 0.66666667,
#        0.        , 0.5       , 0.        , 0.        , 0.10276143,
#        0.66666667, 0.5       , 0.        , 0.        , 0.        ,
# ...

# %%
model_decision_tree = DecisionTreeClassifier(min_impurity_decrease=0.5)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model_decision_tree.fit(X_train, y_train)

model_decision_tree.tree_.impurity
# Out:
# array([0.89984551])
